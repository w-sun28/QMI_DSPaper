# %%
import matplotlib
import numpy as np
import pandas as pd
from datetime import datetime
print("done importing")
# Out:
# done importing

# %%
covid_data = pd.read_csv('covid-data.csv')
covid_data.set_index('date')
covid_data
# Out:
#           location        date  total_cases  new_cases  new_cases_smoothed  \
# 0           Brazil  12/15/2021     22205707     5078.0            4620.571
# 1           Brazil  12/16/2021     22209368     3661.0            3893.143
# 2           Brazil  12/17/2021     22213731     4363.0            3507.143
# 3           Brazil  12/18/2021     22216112     2381.0            3463.857
# 4           Brazil  12/19/2021     22217570     1458.0            3441.429
# ..             ...         ...          ...        ...                 ...
# 300  United States    2/9/2022     77285250   188875.0          222960.571
# 301  United States   2/10/2022     77457316   172066.0          211349.429
# 302  United States   2/11/2022     77667718   210402.0          188384.714
# 303  United States   2/12/2022     77723070    55352.0          181350.286
# 304  United States   2/13/2022     77780002    56932.0          177974.571
#
# ...

# %%
destinations = ['London', 'Paris', 'Seoul']
dates = pd.date_range(start="2021-12-15",end="2022-02-13")

price_data = pd.DataFrame(columns=destinations, index=dates)

for dest in destinations:
    dest_data = pd.read_csv(str(dest) + ".csv")
    dest_data = dest_data[::-1] # reversing dates to match covid data
    price_data[dest] = dest_data['Price'].values

price_data
# Out:
#             London  Paris  Seoul
# 2021-12-15     291    429   1068
# 2021-12-16     291    429   1068
# 2021-12-17     291    426   1063
# 2021-12-18     255    427   1063
# 2021-12-19     255    433   1102
# ...            ...    ...    ...
# 2022-02-09     312    405   1258
# 2022-02-10     390    360   1258
# 2022-02-11     470    418   1230
# 2022-02-12     470    418   1251
# 2022-02-13     472    418   1206
#
# [61 rows x 3 columns]
